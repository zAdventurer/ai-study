# %% [markdown]
# # 机器学习核心算法
#
# ### 机器学习的核心价值
# “什么值得买”
# 推荐系统：推荐算法（协同过滤 -> ）
# 垃圾邮件（短信）过滤：
#     nlp: nlu nlg
#     llm: GPT BERT
# 让机器在过程当中学习规律、预测方向的推到
#     优点：无需显示编程、
#
# 判断是否为AI“”自动化决策、模式识别、预测能力
# ![image.png](attachment:1a01a2db-c1e6-47b3-91ab-3051002ec3fb.png)
#
# ### 算法分类
# 监督学习：有特征、有标签
#     案例：一元一次线性回归
# 无监督学习：仅有特征、具有内在结构
#
# 强化学习：半监督+场景。通过算法实现奖惩模型。
#     算法示例：Q-learn dqn dqqn
#     案例：AlphaGo、扫地机器人
#
# ## 线性回归
# 只有一元一次回归是直线，其他一律按照曲线处理
#
#
# ![image.png](attachment:96a1708f-83df-4c3d-bbce-c2e77ca8b4fa.png)
# ![image.png](attachment:e4dd13b7-a58b-4007-81d5-9c5d288babbc.png)
#
# ## 逻辑回归
# ## 支持向量机
# 不是只有降为可以解决问题，有时候升维也可以更好解决问题。
#
# ## knn算法
# 介绍超参数定义：k是超参数，人为给定的。普通参数是求出来的
#
# ## 决策树算法
# 树的概念：
# ![image.png](attachment:3d720690-e261-4092-b58f-43fc4adb74e4.png)
# 熵
# ![image.png](attachment:377b0624-0a88-475b-b08f-c3768349aa0a.png)
#
# ID3的缺陷
# ![image.png](attachment:58b2bb64-cd81-463c-b440-7fe51baa48e7.png)
# 仔细讲解ID3与CART，c4.5简单了解
# 普通降维和剪枝操作的对比
# ![image.png](attachment:44f44035-7e4b-40fc-ae51-5fb45439d2af.png)
# 在模型构建完成前的是前剪枝，后是后剪枝
# 介绍一下剪枝和降维的区别
#
#
# 问题有多种算法可以解决，关键是用哪一种算法进行解决
