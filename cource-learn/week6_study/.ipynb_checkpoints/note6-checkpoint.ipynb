# %% [markdown]
# # RNN & LSTM & GRU
# ## 时序列建模
# ### 什么是序列数据
# 核心点：顺序的依赖性、上下文相关点、输入变长变短会进一步区分语义
#
# ### 为什么需要特殊模型
# #### 传统局限
# #### 时序建模
# 隐藏状态、参数共享
# #### 参数爆炸
# 记忆单元小、无法区分重要数据和非重要数据
# ![image.png](attachment:1a2c539f-612e-41df-9822-59fa87ac67f8.png)
# #### 应用优势
#
# ### 序列模型发展历程
#
# ## 深度剖析RNN原理
# ### 基本结构RNN
# 拓扑原理
# 展开特性
# 计算局限
# 一个带“记忆”的简单网络
# RNN当中的反向传播就称为BPTT
# ### 隐藏状态的意义
# #### 算法本质
# #### 代码实现细节
# ### 时间反向传播
#
#
# ## ⻔控机制详解LSTM （核心）
# 由于RNN的记忆非常短暂，所以引入了LSTM模型
# ### 核心思想
# 细胞状态：用于解决梯度问题
# 门控原理：遗忘门、输入门、输出门。通过门控原理有效地控制信息的流动
# 与RNN的结构对比
# ![image.png](attachment:90d98435-6f0b-455e-a28e-f43d256f80ca.png)
# 缺点
# ### 遗忘门 -> 决定丢弃什么
# ### 输入门 -> 更新机制，决定要储存什么
# ### 输出门 -> 根据重要信息，决定说什么
# ### 变体和改进LSTM
# 深层结构、双向优化、窥视孔机制、计算优化
#
# ## GRU的结构与特性
# ### GRU 结构解析
# ### GRU 数学公式
# ### GRU vs LSTM
# ![image.png](attachment:e29010a5-1281-42d8-9722-5a06fac722f2.png)
#
# ## 常见问题和解决方案
# ### 常见问题
# #### 梯度异常
# #### 过拟合特征
# #### 长序列失效
# #### 硬件瓶颈
# ### 高级优化技巧
# 混合精读、知识蒸馏、结构搜索
