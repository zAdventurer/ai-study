# %% [markdown]
# # 第一课 总览
#
# ## 向量
# 向量在书籍中使用加粗斜体小写字母展示：***a***
#
# 大白话说 *行向量就是表格的一行数字，列向量就是表格的一列数字*
#
#
# ## 留下的挑战
# 1. 绘制 π 小数点后10W位的0~9热力图
# 2. 使用代码统计小数点后10w位的0~9出现的次数

# %%
# 行向量
import numpy as np
row_vector = np.array([[1, 2, 3]])
column_vector = np.array([[1], [2], [3]])
T_row_vector = row_vector.T
print(f"行向量：{row_vector}\n列向量：\n{column_vector}")
print(column_vector == T_row_vector)
# Out:
# 行向量：[[1 2 3]]
# 列向量：
# [[1]
#  [2]
#  [3]]
# [[ True]
#  [ True]
#  [ True]]
